# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df1= pd.read_csv("college_1.csv")

# %%
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df1[['python','mysql']] = df1[['python','mysql']].astype(int)
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani      82     20              24500           24500
# 1  V.JEEVITHA       82     20              21740           21740
# 2  HEMAVATHI.R     100    100              19680           19680
# 3  Mugunthan S     100     47              10610           10610
# 4  Sathammai.S     100      8               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df2=pd.read_csv("college_2.csv")

# %%
df2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df=pd.concat([df1, df2], axis=0)

# %%
df.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani      82     20              24500           24500
# 1  V.JEEVITHA       82     20              21740           21740
# 2  HEMAVATHI.R     100    100              19680           19680
# 3  Mugunthan S     100     47              10610           10610
# 4  Sathammai.S     100      8               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
df.describe().T
# Out:
#                         count         mean          std  min    25%     50%  \
# python                  119.0    54.344538    44.265271 -1.0    0.0    82.0
# mysql                   119.0    23.478992    33.278447 -1.0    0.0     4.0
# Previous Geekions       119.0  3842.352941  4406.339992  0.0  740.0  2410.0
# CodeKata Score          119.0  4051.764706  4551.951881  0.0  740.0  2410.0
# Rising                  119.0   209.411765   553.445746  0.0    0.0     0.0
# python_en                35.0    29.657143    30.582524 -1.0    0.0    20.0
# computational_thinking   35.0     2.200000     7.015948 -1.0    0.0     0.0
#
#                            75%      max
# python                   100.0    100.0
# mysql                     33.0    100.0
# Previous Geekions       5340.0  24500.0
# CodeKata Score          5975.0  24500.0
# Rising                     0.0   3140.0
# python_en                 52.0    100.0
# computational_thinking     0.0     39.0

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
Exceeded_expectations=df[df['CodeKata Score']>=15000]
Exceeded_expectations.to_csv(r'D:\PYTHON Theory\ass\New folder\Exceeded_expectations.csv', index=False)
Exceeded_expectations
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani      82     20              24500           24500
# 1    V.JEEVITHA       82     20              21740           21740
# 2    HEMAVATHI.R     100    100              19680           19680
# 0  ASHOK KUMAR K     100     31              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 0  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 0                     9.0

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached_expectations=df[df["CodeKata Score"].between(10000, 15000, inclusive = True)]                   
Reached_expectations.to_csv(r'D:\PYTHON Theory\ass\New folder\Reached_expectations.csv', index=False)
Reached_expectations
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S     100     47              10610           10610
# 1            Chandru       0      0              14150           14490
# 2  Ganesh Ramkumar R      -1     24               8790           10790
# 3    Bodipudi Harini      -1     35              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs_Improvement=df[df["CodeKata Score"].between(7000, 10000, inclusive = True)]
                          
Needs_Improvement.to_csv(r'D:\PYTHON Theory\ass\New folder\Needs_Improvement.csv', index=False)
Needs_Improvement
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S     100      8               8980            8980
# 5             NIVEESHWAR S     100      0               8200            8200
# 6            KALAIARASAN K      85     47               7750            7880
# 7     MOHAMED ZUBAIR AHMED      82      4               7020            7020
# 4                VIINU V P      -1     24               9150            9150
# 5               Poojitha Y       0     35               7210            8970
# 6   Gowtham Chandrasekaran      -1      0               7250            8950
# 7                Gowtham R      -1      4               8650            8650
# 8                 shifak N      58      0               5180            8320
# 9                  Balaji       -1     20               6170            8160
# 10                Rushitha      -1     62               7470            8090
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory=df[df['CodeKata Score']<7000]
                          
Unsatisfactory.to_csv(r'D:\PYTHON Theory\ass\New folder\Unsatisfactory.csv', index=False)
Unsatisfactory
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI      27     50               5860            5860
# 9      thamizhpaana      29      0               5500            5500
# 10  Iyappan Samiraj      50     24               5400            5400
# 11     Ponniyamma.R     100     11               5380            5380
# 12        SABAPATHI     100      0               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j      24      0               2380            2380
# 31       AMARNATH D      -1     12               1890            1890
# 32             bala      32      0               1720            1720
# 33             XY Z      -1     -1                  0               0
# 34        Hariharan      -1     -1                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
Previous_Geekions_vs_CodeKata_Score=df[['Previous Geekions','CodeKata Score']].mean(axis=1)

Previous_Geekions_vs_CodeKata_Score
# Out:
# 0     24500.0
# 1     21740.0
# 2     19680.0
# 3     10610.0
# 4      8980.0
#        ...
# 30     2380.0
# 31     1890.0
# 32     1720.0
# 33        0.0
# 34        0.0
# Length: 119, dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
Previous_Geekions_vs_CodeKata_Score.count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
m= df['mysql'].mean
m
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      20
# 1      20
# 2     100
# 3      47
# 4       8
#      ...
# 30      0
# 31     12
# 32      0
# 33     -1
# 34     -1
# Name: mysql, Length: 119, dtype: int64>

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_stars_of_the_week=df.nlargest(3, 'Rising')
rising_stars_of_the_week
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N      58      0               5180            8320
# 2   Ganesh Ramkumar R      -1     24               8790           10790
# 18     Narasimhan Y L      -1      0               4800            6800
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 2         Computer Science and Engineering    2000       55.0
# 18        Computer Science and Engineering    2000       -1.0
#
#     computational_thinking
# 8                      0.0
# 2                      6.0
# 18                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
Shining_stars_of_the_week=df.nlargest(3, 'CodeKata Score')
Shining_stars_of_the_week
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani      82     20              24500           24500
# 1  V.JEEVITHA       82     20              21740           21740
# 2  HEMAVATHI.R     100    100              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
D=df.groupby(['Department'])['CodeKata Score'].sum()
D.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='CodeKata Score'>], dtype=object)

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
a=df.groupby(['Department'])['CodeKata Score'].max()
a
# Out:
# Department
# Computer Science and Engineering             24500
# Electronics and Communication Engineering    10040
# Electronics and Electrical Engineering       19400
# Name: CodeKata Score, dtype: int64

# %%
a.plot.barh()
# Out:
# <AxesSubplot:ylabel='Department'>
